# %%
import requests
from bs4 import BeautifulSoup
import pandas

class GetListOfBooks:
    
    def __init__(self,url):
        self.url = url
        self.list=[]
    
    def getPageNum(self):
        totalPageButton = self.parseUrl(self.url).find("div",{"class":"pagination"}).find_all("a")
        totalPages = totalPageButton[len(totalPageButton)-2]
        return int(totalPages.text)
        
        
    def parseUrl(self,url):
        r = requests.get(url)
        c = r.content
        return BeautifulSoup(c,"html.parser")
    
    def getPageContent(self,url):
        allTableRow = self.parseUrl(url).find_all("tr")
        for row in allTableRow:
            tableData = row.find_all("td")
            if len(tableData) == 2:
                bookList={}
                for data in tableData:
                    try:
                        bookList["Book Name"] = data.find("div",{"class":"content"}).text
                    except:
                        bookList["Author Name"] = data.text
                self.list.append(bookList)
        
    
    def getData(self):
        self.getPageContent(self.url)
        for num in range(2,self.getPageNum()+1):
            url = "https://thawing-ridge-65567.herokuapp.com/books?page="+str(num)
            self.getPageContent(url)

# %%
extractdata = GetListOfBooks("https://thawing-ridge-65567.herokuapp.com/books")
extractdata.getData()

# %%
df = pandas.DataFrame(extractdata.list, columns= ["Book Name","Author Name"])
# df
df.to_csv("bookList.csv")

# %%
# run df to display table
df
# Out:
#                                              Book Name  \
# 0                                   How to Read a Book
# 1                                       This Is a Book
# 2                              HTML5 for Web Designers
# 3                                          Hey Ladies!
# 4                           A History of Russian Music
# 5                                   This is Not a Book
# 6                                               Venice
# 7                           How to Cook Without a Book
# 8              A Geography of Victorian Gothic Fiction
# 9                                   A European Memory?
# 10                   A Grammar of the Turkish Language
# 11                 A History of Modern Chinese Fiction
# 12                    A Concise History of Photography
# 13                            Peace As a Women's Issue
# 14                         Reports from a Wild Country
# 15                                           Company K
# 16                                           Bollywood
# 17   A Journal of a Voyage to the South Seas, in Hi...
# 18                                  New World A-Coming
# 19   A Handbook of Research Methods for Clinical an...
# 20                                  A Holocaust Reader
# 21                                          I Am Peace
# 22                           Letters to a Young Doctor
# 23                           A Book of Luminous Things
# 24                                           Gilgamesh
# 25                                       A Man's Place
# 26                              The Americans at D-Day
# 27                  A Sourcebook on Naturalist Theatre
# 28   A History of Africa: African nationalism and t...
# 29                                      A Few Good Men
# ..                                                 ...
# 965  Applied Laplace Transforms and Z-Transforms fo...
# 966                            Cuban Music from A to Z
# 967                                                  Z
# 968                        Health Literacy From A to Z
# 969                                         Cattitudes
# 970               An A to Z of Places and Things Saudi
# 971                               Thinking from A to Z
# 972  Jay-Z (the Library of Hip-Hop Biographies) (La...
# 973                                    DNA from A to Z
# 974                              Songs in the Key of Z
# 975                                        Bugs A to Z
# 976                         Z'miroth Ut'filoth Yisroel
# 977                   A to Z of Sports Cars, 1945-1990
# 978                             The A to Z of Malaysia
# 979                          Learning Theories, A to Z
# 980                             The Truth about Babies
# 981                                Phonics from A to Z
# 982                           The A to Z of the Druzes
# 983                         The A to Z of the Cold War
# 984                                Algebra from A to Z
# 985                                    Oracle on IBM Z
# 986              Food in the Ancient World from A to Z
# 987                 Mergers & Acquisitions from A to Z
# 988                                              Jay-Z
# 989                              The A to Z of Vietnam
# 990                             Norse Mythology A to Z
# 991                         Movement Activities A to Z
# 992                                                 Z.
# 993                          Animal Ingredients A to Z
# 994                                      Seeing Past Z
#
#                       Author Name
# 0              Mortimer J. Adler
# 1                 Demetri Martin
# 2                   Jeremy Keith
# 3             Michelle Markowitz
# 4                   Francis Maes
# 5                     Keri Smith
# 6       David Sanderson Chambers
# 7                   Pam Anderson
# 8                 Robert Mighall
# 9              Małgorzata Pakier
# 10                Thomas Vaughan
# 11               Chih-tsing Hsia
# 12              Helmut Gernsheim
# 13          Harriet Hyman Alonso
# 14             Deborah Bird Rose
# 15                 William March
# 16               Tejaswini Ganti
# 17              Sydney Parkinson
# 18             Judith Weisenfeld
# 19                  Jeremy Miles
# 20            Lucy S. Dawidowicz
# 21                   Susan Verde
# 22                Richard Selzer
# 23                Czesław Miłosz
# 24                 John R. Maier
# 25                     John Tosh
# 26               John C. McManus
# 27                   C. D. Innes
# 28                    Assa Okoth
# 29                   Jan Nattier
# ..                            ...
# 965                     Urs Graf
# 966                 Helio Orovio
# 967          Vassilis Vassilikos
# 968                Helen Osborne
# 969        Elizabeth King Brownd
# 970                Kathy Cuddihy
# 971              Nigel Warburton
# 972                 Bridget Heos
# 973             Daniel H. Farkas
# 974                 Irwin Chusid
# 975              Kimberly Bayley
# 976                      no name
# 977                Mike Lawrence
# 978                 Keat Gin Ooi
# 979             David C. Leonard
# 980                   Ian Sansom
# 981                Wiley Blevins
# 982                Samy S. Swayd
# 983                 Joseph Smith
# 984       Adolph Winkler Goodman
# 985              Susan Adamovich
# 986                 Andrew Dalby
# 987            Andrew J. Sherman
# 988                Julius Bailey
# 989     Bruce McFarland Lockhart
# 990  Facts On File, Incorporated
# 991                  Holly Burns
# 992              Kenward Elmslie
# 993        E.G. Smith Collective
# 994                 Beth Kephart
#
# [995 rows x 2 columns]
